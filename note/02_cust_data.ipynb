# %%
import pandas as pd
customers = pd.read_csv(
    "../ecommerce-data-project/data/raw data/olist_customers_dataset.csv"
)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.shape
# Out:
# (99441, 5)

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %%
customers["customer_state"].nunique()
# Out:
# 27

# %%
customers["customer_city"].nunique()
# Out:
# 4119

# %%
customers["customer_state"].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %% [markdown]
# # Comparing and understanding

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %%
customers.shape
# Out:
# (99441, 5)

# %% [markdown]
# # Discovery --
# ## Cust_id has same val as rows <br>
# ## But cust_uniq_id as < than original row value <br>
# ## hence there are some repeated entries in cust_uniq_id

# %%
customers["customer_unique_id"].value_counts().head(10)


# output---- 
# the code shows the repeated entries along with its reps
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# dc813062e0fc23409cd255f7f53c7074     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# de34b16117594161a6a89c50b289d35a     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# Name: count, dtype: int64

# %%
# inspectng one repeated customer

customers[
    customers["customer_unique_id"] == "8d50f5eadf50201ccdcedfb9e2ac8455"

]
# Out:
#                             customer_id                customer_unique_id  \
# 14186  1bd3585471932167ab72a84955ebefea  8d50f5eadf50201ccdcedfb9e2ac8455
# 15321  a8fabc805e9a10a3c93ae5bff642b86b  8d50f5eadf50201ccdcedfb9e2ac8455
# 16654  897b7f72042714efaa64ac306ba0cafc  8d50f5eadf50201ccdcedfb9e2ac8455
# 36122  b2b13de0770e06de50080fea77c459e6  8d50f5eadf50201ccdcedfb9e2ac8455
# 38073  42dbc1ad9d560637c9c4c1533746f86d  8d50f5eadf50201ccdcedfb9e2ac8455
# 40141  dfb941d6f7b02f57a44c3b7c3fefb44b  8d50f5eadf50201ccdcedfb9e2ac8455
# 48614  65f9db9dd07a4e79b625effa4c868fcb  8d50f5eadf50201ccdcedfb9e2ac8455
# 52574  1c62b48fb34ee043310dcb233caabd2e  8d50f5eadf50201ccdcedfb9e2ac8455
# 58707  a682769c4bc10fc6ef2101337a6c83c9  8d50f5eadf50201ccdcedfb9e2ac8455
# 67996  6289b75219d757a56c0cce8d9e427900  8d50f5eadf50201ccdcedfb9e2ac8455
# 72745  3414a9c813e3ca02504b8be8b2deb27f  8d50f5eadf50201ccdcedfb9e2ac8455
# 74510  0e4fdc084a6b9329ed55d62dcd653ccf  8d50f5eadf50201ccdcedfb9e2ac8455
# ...

# %%
customers[
    customers["customer_city"].isnull()|
    customers["customer_state"].isnull()
]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customers["customer_id"].isnull().sum()
# Out:
# np.int64(0)

# %%
customers["customer_unique_id"].isnull().sum()
# Out:
# np.int64(0)

# %%
print("nunique customer_id:", customers["customer_id"].nunique())
print("nunique customer_unique_id:", customers["customer_unique_id"].nunique())
print("top 10 customer_unique_id value_counts:\n", customers["customer_unique_id"].value_counts().head(10))
print("nulls in customer_id:", customers["customer_id"].isnull().sum())
print("nulls in customer_unique_id:", customers["customer_unique_id"].isnull().sum())
# Out:
# nunique customer_id: 99441
# nunique customer_unique_id: 96096
# top 10 customer_unique_id value_counts:
#  customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# dc813062e0fc23409cd255f7f53c7074     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# de34b16117594161a6a89c50b289d35a     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# Name: count, dtype: int64
# nulls in customer_id: 0
# nulls in customer_unique_id: 0

# %%
customers[
    customers["customer_unique_id"] == "8d50f5eadf50201ccdcedfb9e2ac8455"
]
# Out:
#                             customer_id                customer_unique_id  \
# 14186  1bd3585471932167ab72a84955ebefea  8d50f5eadf50201ccdcedfb9e2ac8455
# 15321  a8fabc805e9a10a3c93ae5bff642b86b  8d50f5eadf50201ccdcedfb9e2ac8455
# 16654  897b7f72042714efaa64ac306ba0cafc  8d50f5eadf50201ccdcedfb9e2ac8455
# 36122  b2b13de0770e06de50080fea77c459e6  8d50f5eadf50201ccdcedfb9e2ac8455
# 38073  42dbc1ad9d560637c9c4c1533746f86d  8d50f5eadf50201ccdcedfb9e2ac8455
# 40141  dfb941d6f7b02f57a44c3b7c3fefb44b  8d50f5eadf50201ccdcedfb9e2ac8455
# 48614  65f9db9dd07a4e79b625effa4c868fcb  8d50f5eadf50201ccdcedfb9e2ac8455
# 52574  1c62b48fb34ee043310dcb233caabd2e  8d50f5eadf50201ccdcedfb9e2ac8455
# 58707  a682769c4bc10fc6ef2101337a6c83c9  8d50f5eadf50201ccdcedfb9e2ac8455
# 67996  6289b75219d757a56c0cce8d9e427900  8d50f5eadf50201ccdcedfb9e2ac8455
# 72745  3414a9c813e3ca02504b8be8b2deb27f  8d50f5eadf50201ccdcedfb9e2ac8455
# 74510  0e4fdc084a6b9329ed55d62dcd653ccf  8d50f5eadf50201ccdcedfb9e2ac8455
# ...

# %% [markdown]
# # Testing relationship

# %%
orders = pd.read_csv("../ecommerce-data-project/data/raw data/olist_orders_dataset.csv")

# %%
orders[
    orders["customer_id"] == "1bd3585471932167ab72a84955ebefea"
]
# Out:
#                                order_id                       customer_id  \
# 39449  b850a16d8faf65a74c51287ef34379ce  1bd3585471932167ab72a84955ebefea
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 39449    delivered      2017-11-22 20:01:53  2017-11-22 20:12:32
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 39449          2017-11-24 16:07:56           2017-11-27 18:49:13
#
#       order_estimated_delivery_date
# 39449           2017-12-04 00:00:00
